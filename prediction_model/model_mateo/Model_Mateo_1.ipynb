# %%
import pandas as pd

df_eth = pd.read_parquet("../../data/features/DATA_0/ETH_EUR.parquet")
df_xbt = pd.read_parquet("../../data/features/DATA_0/XBT_EUR.parquet")

# %%
df_eth
# Out:
#               bid-ask-imbalance-5-levels   spread  slope-bid-5-levels  \
# timestamp
# 1.748488e+09                    0.274159  0.01000           -0.003626
# 1.748488e+09                    0.513330  0.01000           -0.003626
# 1.748488e+09                    0.265161  0.01000           -0.003626
# 1.748488e+09                    0.320687  0.01000           -0.002743
# 1.748488e+09                    0.199271  0.01000           -0.002171
# ...                                  ...      ...                 ...
# 1.748523e+09                    0.194011  0.14000           -0.012486
# 1.748523e+09                    0.156433  0.22554           -0.021134
# 1.748523e+09                    0.660999  0.64000           -0.014860
# 1.748523e+09                    0.660998  0.63000           -0.015324
# 1.748523e+09                   -0.168840  0.95000           -0.016132
#
#               slope-ask-5-levels  vwap-bid-5-levels  vwap-ask-5-levels  \
# timestamp
# 1.748488e+09            0.005356                0.0                0.0
# 1.748488e+09            0.006811                0.0                0.0
# 1.748488e+09            0.003511                0.0                0.0
# 1.748488e+09            0.003511                0.0                0.0
# 1.748488e+09            0.003511                0.0                0.0
# ...                          ...                ...                ...
# 1.748523e+09            0.014387                0.0                0.0
# 1.748523e+09            0.028554                0.0                0.0
# 1.748523e+09            0.118312                0.0                0.0
# 1.748523e+09            0.118312                0.0                0.0
# 1.748523e+09            0.007253                0.0                0.0
#
#               liquidity-ratio-5-levels  rate-inst-volatility-20-sample  \
# timestamp
# 1.748488e+09                  1.755425                             NaN
# 1.748488e+09                  3.109557                             NaN
# 1.748488e+09                  1.721685                             NaN
# 1.748488e+09                  1.944153                             NaN
# 1.748488e+09                  1.497725                             NaN
# ...                                ...                             ...
# 1.748523e+09                  1.481425                        0.008172
# 1.748523e+09                  1.370885                        0.007689
# 1.748523e+09                  4.899679                        0.007998
# 1.748523e+09                  4.899679                        0.007535
# 1.748523e+09                  0.711098                        0.006778
#
#               rate-momentum-20-sample  rate-mid-price-trend-20-sample  \
# timestamp
# 1.748488e+09                      NaN                             NaN
# 1.748488e+09                      NaN                             NaN
# 1.748488e+09                      NaN                             NaN
# 1.748488e+09                      NaN                             NaN
# 1.748488e+09                      NaN                             NaN
# ...                               ...                             ...
# 1.748523e+09                -0.055000                     2376.306553
# 1.748523e+09                -0.092770                     2376.301914
# 1.748523e+09                -0.158925                     2376.293968
# 1.748523e+09                 0.040000                     2376.295968
# 1.748523e+09                 0.200000                     2376.305968
#
#               rate-bid-volume-level-1  rate-ask-volume-level-1  \
# timestamp
# 1.748488e+09                      NaN                      NaN
# 1.748488e+09                      NaN                      NaN
# 1.748488e+09                      NaN                      NaN
# 1.748488e+09                      NaN                      NaN
# 1.748488e+09                      NaN                      NaN
# ...                               ...                      ...
# 1.748523e+09                27.741842                14.567612
# 1.748523e+09                26.475665                13.936600
# 1.748523e+09                25.912914                13.936600
# 1.748523e+09                25.912914                13.936600
# 1.748523e+09                24.055945                13.936600
#
#               V-bid-5-levels  V-ask-5-levels  inst-return  \
# timestamp
# 1.748488e+09      132.389727       75.417476          NaN
# 1.748488e+09      132.389727       42.575110     0.000000
# 1.748488e+09      132.389727       76.895429     0.000000
# 1.748488e+09      149.496442       76.895429     0.000000
# 1.748488e+09      115.168181       76.895429     0.000000
# ...                      ...             ...          ...
# 1.748523e+09       57.663922       38.924636     0.513256
# 1.748523e+09       29.693231       21.659905  -113.108435
# 1.748523e+09       21.534944        4.395174   -30.096067
# 1.748523e+09       21.534942        4.395174     2.328875
# 1.748523e+09       24.689716       34.720575   244.654991
#
#               return-all-signed-for-5-ms  return-all-signed-for-10-ms  \
# timestamp
# 1.748488e+09                           0                            0
# 1.748488e+09                           0                            0
# 1.748488e+09                           0                            0
# 1.748488e+09                           0                            0
# 1.748488e+09                           0                            0
# ...                                  ...                          ...
# 1.748523e+09                           0                            0
# 1.748523e+09                           0                            0
# 1.748523e+09                           0                            0
# 1.748523e+09                           1                            1
# 1.748523e+09                           1                            1
#
#               return-all-signed-for-20-ms
# timestamp
# 1.748488e+09                            0
# 1.748488e+09                            0
# 1.748488e+09                            0
# 1.748488e+09                            0
# 1.748488e+09                            0
# ...                                   ...
# 1.748523e+09                            0
# 1.748523e+09                            0
# 1.748523e+09                            0
# 1.748523e+09                            1
# 1.748523e+09                            1
#
# [1817685 rows x 18 columns]

# %%
df_xbt
# Out:
#               bid-ask-imbalance-5-levels  spread  slope-bid-5-levels  \
# timestamp
# 1.748488e+09                   -0.024111     0.1           -0.584545
# 1.748488e+09                    0.047148     0.1           -0.584545
# 1.748488e+09                    0.047148     0.1           -0.584545
# 1.748488e+09                   -0.086289     0.1           -0.584545
# 1.748488e+09                    0.060407     0.1           -0.584545
# ...                                  ...     ...                 ...
# 1.748523e+09                   -0.167708     0.1           -1.368001
# 1.748523e+09                    0.071850     0.1           -0.865069
# 1.748523e+09                    0.147739     0.1           -0.988139
# 1.748523e+09                    0.055872     0.1           -0.865069
# 1.748523e+09                    0.103255     0.1           -0.735322
#
#               slope-ask-5-levels  vwap-bid-5-levels  vwap-ask-5-levels  \
# timestamp
# 1.748488e+09            0.940570                0.0                0.0
# 1.748488e+09            1.177719                0.0                0.0
# 1.748488e+09            1.177719                0.0                0.0
# 1.748488e+09            0.829708                0.0                0.0
# 1.748488e+09            0.980247                0.0                0.0
# ...                          ...                ...                ...
# 1.748523e+09            0.379757                0.0                0.0
# 1.748523e+09            0.495702                0.0                0.0
# 1.748523e+09            1.014675                0.0                0.0
# 1.748523e+09            0.556288                0.0                0.0
# 1.748523e+09            0.617360                0.0                0.0
#
#               liquidity-ratio-5-levels  rate-inst-volatility-20-sample  \
# timestamp
# 1.748488e+09                  0.952914                             NaN
# 1.748488e+09                  1.098961                             NaN
# 1.748488e+09                  1.098961                             NaN
# 1.748488e+09                  0.841131                             NaN
# 1.748488e+09                  1.128582                             NaN
# ...                                ...                             ...
# 1.748523e+09                  0.712757                   -1.118703e-07
# 1.748523e+09                  1.154823                   -1.118703e-07
# 1.748523e+09                  1.346699                   -1.118703e-07
# 1.748523e+09                  1.118358                   -1.118703e-07
# 1.748523e+09                  1.230288                   -1.118703e-07
#
#               rate-momentum-20-sample  rate-mid-price-trend-20-sample  \
# timestamp
# 1.748488e+09                      NaN                             NaN
# 1.748488e+09                      NaN                             NaN
# 1.748488e+09                      NaN                             NaN
# 1.748488e+09                      NaN                             NaN
# 1.748488e+09                      NaN                             NaN
# ...                               ...                             ...
# 1.748523e+09             0.000000e+00                        95772.05
# 1.748523e+09             0.000000e+00                        95772.05
# 1.748523e+09             0.000000e+00                        95772.05
# 1.748523e+09             0.000000e+00                        95772.05
# 1.748523e+09             1.455192e-11                        95772.05
#
#               rate-bid-volume-level-1  rate-ask-volume-level-1  \
# timestamp
# 1.748488e+09                      NaN                      NaN
# 1.748488e+09                      NaN                      NaN
# 1.748488e+09                      NaN                      NaN
# 1.748488e+09                      NaN                      NaN
# 1.748488e+09                      NaN                      NaN
# ...                               ...                      ...
# 1.748523e+09                 0.033861                 0.529792
# 1.748523e+09                 0.033861                 0.529792
# 1.748523e+09                 0.033861                 0.529792
# 1.748523e+09                 0.033861                 0.529792
# 1.748523e+09                 0.033861                 0.529792
#
#               V-bid-5-levels  V-ask-5-levels   inst-return  \
# timestamp
# 1.748488e+09        8.211519        8.617270           NaN
# 1.748488e+09        8.211519        7.472074  0.000000e+00
# 1.748488e+09        8.211519        7.472074  0.000000e+00
# 1.748488e+09        8.211519        9.762472  0.000000e+00
# 1.748488e+09        8.211519        7.275961  0.000000e+00
# ...                      ...             ...           ...
# 1.748523e+09        6.944440        9.743071 -4.702402e-11
# 1.748523e+09        9.247813        8.007988  4.295226e-08
# 1.748523e+09        8.096060        6.011780 -1.056675e-10
# 1.748523e+09        9.247813        8.269100  0.000000e+00
# 1.748523e+09        9.247655        7.516660  6.612693e-08
#
#               return-all-signed-for-5-ms  return-all-signed-for-10-ms  \
# timestamp
# 1.748488e+09                           0                            0
# 1.748488e+09                           0                            0
# 1.748488e+09                           0                            0
# 1.748488e+09                           0                            0
# 1.748488e+09                           0                            0
# ...                                  ...                          ...
# 1.748523e+09                           0                            0
# 1.748523e+09                           0                            0
# 1.748523e+09                           0                            0
# 1.748523e+09                           0                            0
# 1.748523e+09                           1                            1
#
#               return-all-signed-for-20-ms
# timestamp
# 1.748488e+09                            0
# 1.748488e+09                            0
# 1.748488e+09                            0
# 1.748488e+09                            0
# 1.748488e+09                            0
# ...                                   ...
# 1.748523e+09                            0
# 1.748523e+09                            0
# 1.748523e+09                            0
# 1.748523e+09                            0
# 1.748523e+09                            1
#
# [563395 rows x 18 columns]

# %%
import numpy as np

target = df_eth["return-all-signed-for-5-ms"]

#pre_features = df_xbt[["return-all-signed-for-20-ms", "return-all-signed-for-10-ms", "return-all-signed-for-5-ms", "bid-ask-imbalance-5-levels", "spread"]]
pre_features = df_xbt[["bid-ask-imbalance-5-levels", "spread", "inst-return", "V-bid-5-levels", "V-ask-5-levels", "slope-bid-5-levels", "slope-ask-5-levels"]]

target_timestamp = target.index.values
feature_timestamp = pre_features.index.values
filtered_indicies = np.searchsorted(feature_timestamp, target_timestamp, side="left")

filtered_indicies = filtered_indicies[filtered_indicies < len(pre_features)]
pre_features_filtered = pre_features.iloc[filtered_indicies]

pre_features_filtered
# Out:
#               bid-ask-imbalance-5-levels  spread   inst-return  \
# timestamp
# 1.748488e+09                    0.047148     0.1  0.000000e+00
# 1.748488e+09                    0.047148     0.1  0.000000e+00
# 1.748488e+09                    0.047148     0.1  0.000000e+00
# 1.748488e+09                    0.047148     0.1  0.000000e+00
# 1.748488e+09                    0.047148     0.1  0.000000e+00
# ...                                  ...     ...           ...
# 1.748523e+09                    0.147739     0.1 -1.056675e-10
# 1.748523e+09                    0.147739     0.1 -1.056675e-10
# 1.748523e+09                    0.147739     0.1 -1.056675e-10
# 1.748523e+09                    0.147739     0.1 -1.056675e-10
# 1.748523e+09                    0.147739     0.1 -1.056675e-10
#
#               V-bid-5-levels  V-ask-5-levels  slope-bid-5-levels  \
# timestamp
# 1.748488e+09        8.211519        7.472074           -0.584545
# 1.748488e+09        8.211519        7.472074           -0.584545
# 1.748488e+09        8.211519        7.472074           -0.584545
# 1.748488e+09        8.211519        7.472074           -0.584545
# 1.748488e+09        8.211519        7.472074           -0.584545
# ...                      ...             ...                 ...
# 1.748523e+09        8.096060        6.011780           -0.988139
# 1.748523e+09        8.096060        6.011780           -0.988139
# 1.748523e+09        8.096060        6.011780           -0.988139
# 1.748523e+09        8.096060        6.011780           -0.988139
# 1.748523e+09        8.096060        6.011780           -0.988139
#
#               slope-ask-5-levels
# timestamp
# 1.748488e+09            1.177719
# 1.748488e+09            1.177719
# 1.748488e+09            1.177719
# 1.748488e+09            1.177719
# 1.748488e+09            1.177719
# ...                          ...
# 1.748523e+09            1.014675
# 1.748523e+09            1.014675
# 1.748523e+09            1.014675
# 1.748523e+09            1.014675
# 1.748523e+09            1.014675
#
# [1817685 rows x 7 columns]

# %%
# Reset index of pre_features_filtered to match target's index
pre_features_aligned = pre_features_filtered.reset_index(drop=True)
pre_features_aligned.index = target.index

# Concatenate pre_features_aligned and target
combined_data = pd.concat([pre_features_aligned, target], axis=1)
combined_data.dropna(inplace=True)
combined_data
# Out:
#               bid-ask-imbalance-5-levels  spread   inst-return  \
# timestamp
# 1.748488e+09                    0.047148     0.1  0.000000e+00
# 1.748488e+09                    0.047148     0.1  0.000000e+00
# 1.748488e+09                    0.047148     0.1  0.000000e+00
# 1.748488e+09                    0.047148     0.1  0.000000e+00
# 1.748488e+09                    0.047148     0.1  0.000000e+00
# ...                                  ...     ...           ...
# 1.748523e+09                    0.147739     0.1 -1.056675e-10
# 1.748523e+09                    0.147739     0.1 -1.056675e-10
# 1.748523e+09                    0.147739     0.1 -1.056675e-10
# 1.748523e+09                    0.147739     0.1 -1.056675e-10
# 1.748523e+09                    0.147739     0.1 -1.056675e-10
#
#               V-bid-5-levels  V-ask-5-levels  slope-bid-5-levels  \
# timestamp
# 1.748488e+09        8.211519        7.472074           -0.584545
# 1.748488e+09        8.211519        7.472074           -0.584545
# 1.748488e+09        8.211519        7.472074           -0.584545
# 1.748488e+09        8.211519        7.472074           -0.584545
# 1.748488e+09        8.211519        7.472074           -0.584545
# ...                      ...             ...                 ...
# 1.748523e+09        8.096060        6.011780           -0.988139
# 1.748523e+09        8.096060        6.011780           -0.988139
# 1.748523e+09        8.096060        6.011780           -0.988139
# 1.748523e+09        8.096060        6.011780           -0.988139
# 1.748523e+09        8.096060        6.011780           -0.988139
#
#               slope-ask-5-levels  return-all-signed-for-5-ms
# timestamp
# 1.748488e+09            1.177719                           0
# 1.748488e+09            1.177719                           0
# 1.748488e+09            1.177719                           0
# 1.748488e+09            1.177719                           0
# 1.748488e+09            1.177719                           0
# ...                          ...                         ...
# 1.748523e+09            1.014675                           0
# 1.748523e+09            1.014675                           0
# 1.748523e+09            1.014675                           0
# 1.748523e+09            1.014675                           1
# 1.748523e+09            1.014675                           1
#
# [1816244 rows x 8 columns]

# %%
target = combined_data["return-all-signed-for-5-ms"]
data = combined_data.drop(columns=["return-all-signed-for-5-ms"])
# Filter out rows where target equals 1
mask = target != 1
target = target[mask]
data = data[mask]

print(f"Data shape after filtering out class 1: {data.shape}")
print(f"Target shape after filtering out class 1: {target.shape}")
print("Remaining class distribution:")
print(target.value_counts().sort_index())
# Out:
# Data shape after filtering out class 1: (1816242, 7)
# Target shape after filtering out class 1: (1816242,)
# Remaining class distribution:
# return-all-signed-for-5-ms
# -1     202232
#  0    1614010
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier

# Check class distribution
print("Class distribution in target:")
print(target.value_counts().sort_index())
print("\nClass proportions:")
print(target.value_counts(normalize=True).sort_index())

# Split the data into training and testing sets
# Temporal split - test set contains the last 20% of data chronologically
split_index = int(len(data) * 0.8)
X_train, X_test = data.iloc[:split_index], data.iloc[split_index:]
y_train, y_test = target.iloc[:split_index], target.iloc[split_index:]

# Calculate class weights to handle imbalance
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(zip(np.unique(y_train), class_weights))
print(f"\nClass weights: {class_weight_dict}")

# Create and train a small Random Forest model with balanced class weights
rf_model = RandomForestClassifier(
    n_estimators=100,  # Small number of trees for a quick test
    max_depth=3,  # Limit depth to prevent overfitting
    class_weight="balanced",
    random_state=42,
    n_jobs=-1  # Use all available cores
)
rf_model.fit(X_train, y_train)

# Make predictions
y_pred_rf = rf_model.predict(X_test)

# Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"\nSmall Random Forest Accuracy: {accuracy_rf:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_rf, labels=[-1, 0]))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_rf, labels=[-1, 0]))

# Feature importance
feature_importance = pd.DataFrame({
    'feature': data.columns,
    'importance': rf_model.feature_importances_
}).sort_values('importance', ascending=False)
print("\nFeature Importance:")
print(feature_importance)
# Out:
# Class distribution in target:
# return-all-signed-for-5-ms
# -1     202232
#  0    1614010
# Name: count, dtype: int64
#
# Class proportions:
# return-all-signed-for-5-ms
# -1    0.111346
#  0    0.888654
# Name: proportion, dtype: float64
#
# Class weights: {-1: 4.377249639997349, 0: 0.5644786957798701}
#
# Small Random Forest Accuracy: 0.2669
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.10      0.76      0.17     36261
#            0       0.89      0.21      0.34    326988
#
#     accuracy                           0.27    363249
#    macro avg       0.49      0.49      0.26    363249
# weighted avg       0.81      0.27      0.33    363249
#
#
# Confusion Matrix:
# [[ 27720   8541]
#  [257754  69234]]
#
# Feature Importance:
#                       feature  importance
# 5          slope-bid-5-levels    0.291436
# 6          slope-ask-5-levels    0.282437
# 0  bid-ask-imbalance-5-levels    0.180127
# 4              V-ask-5-levels    0.127723
# 3              V-bid-5-levels    0.104642
# 1                      spread    0.012664
# 2                 inst-return    0.000971

# %%
from sklearn.dummy import DummyClassifier

# Create dummy classifiers with different strategies
dummy_most_frequent = DummyClassifier(strategy="most_frequent", random_state=42)
dummy_stratified = DummyClassifier(strategy="stratified", random_state=42)

# Fit dummy classifiers
dummy_most_frequent.fit(X_train, y_train)
dummy_stratified.fit(X_train, y_train)

# Make predictions
y_pred_dummy_freq = dummy_most_frequent.predict(X_test)
y_pred_dummy_strat = dummy_stratified.predict(X_test)

# Evaluate dummy classifiers
accuracy_dummy_freq = accuracy_score(y_test, y_pred_dummy_freq)
accuracy_dummy_strat = accuracy_score(y_test, y_pred_dummy_strat)

print("=== COMPARISON WITH DUMMY CLASSIFIERS ===")
print(f"Random Forest Accuracy: {accuracy_rf:.4f}")
print(f"Dummy (Most Frequent) Accuracy: {accuracy_dummy_freq:.4f}")
print(f"Dummy (Stratified) Accuracy: {accuracy_dummy_strat:.4f}")
print(f"\nImprovement over Most Frequent: {accuracy_rf - accuracy_dummy_freq:.4f}")
print(f"Improvement over Stratified: {accuracy_rf - accuracy_dummy_strat:.4f}")

print("\n=== DUMMY CLASSIFIER REPORTS ===")
print("\nDummy (Most Frequent) Classification Report:")
print(classification_report(y_test, y_pred_dummy_freq, labels=[-1, 0]))
print("\nDummy (Stratified) Classification Report:")
print(classification_report(y_test, y_pred_dummy_strat, labels=[-1, 0]))
# Out:
# === COMPARISON WITH DUMMY CLASSIFIERS ===
# Random Forest Accuracy: 0.2669
# Dummy (Most Frequent) Accuracy: 0.9002
# Dummy (Stratified) Accuracy: 0.8086
#
# Improvement over Most Frequent: -0.6333
# Improvement over Stratified: -0.5417
#
# === DUMMY CLASSIFIER REPORTS ===
#
# Dummy (Most Frequent) Classification Report:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00     36261
#            0       0.90      1.00      0.95    326988
#
#     accuracy                           0.90    363249
#    macro avg       0.45      0.50      0.47    363249
# weighted avg       0.81      0.90      0.85    363249
#
#
# Dummy (Stratified) Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.10      0.11      0.10     36261
#            0       0.90      0.89      0.89    326988
#
#     accuracy                           0.81    363249
#    macro avg       0.50      0.50      0.50    363249
# weighted avg       0.82      0.81      0.81    363249

# %%
import joblib
import os

# save Model
os.makedirs("../../data/models/mateo", exist_ok=True)
joblib.dump(rf_model, "../../predictors/mateo/rf_model_5ms.joblib")
# Out:
# ['../data/models/mateo/rf_model_5ms.joblib']

# %%
df_eth = pd.read_parquet("../data/features/DATA_1/ETH_EUR.parquet")
df_xbt = pd.read_parquet("../data/features/DATA_1/XBT_EUR.parquet")

df_xbt
# Out:
#               bid-ask-imbalance-5-levels  spread  slope-bid-5-levels  \
# timestamp
# 1.748352e+09                    0.977859     0.1           -1.218478
# 1.748352e+09                    0.975521     0.1           -1.337494
# 1.748352e+09                    0.975530     0.1           -1.336992
# 1.748352e+09                    0.975572     0.1           -1.334694
# 1.748352e+09                    0.975572     0.1           -1.334694
# ...                                  ...     ...                 ...
# 1.748429e+09                    0.611979     0.1           -0.170271
# 1.748429e+09                    0.611979     0.1           -0.170271
# 1.748429e+09                    0.611978     0.1           -0.170271
# 1.748429e+09                    0.611978     0.1           -0.170271
# 1.748429e+09                    0.611973     0.1           -0.170274
#
#               slope-ask-5-levels  vwap-bid-5-levels  vwap-ask-5-levels  \
# timestamp
# 1.748352e+09          365.547502                0.0                0.0
# 1.748352e+09          365.547502                0.0                0.0
# 1.748352e+09          365.547502                0.0                0.0
# 1.748352e+09          365.547502                0.0                0.0
# 1.748352e+09          365.547502                0.0                0.0
# ...                          ...                ...                ...
# 1.748429e+09            8.724197                0.0                0.0
# 1.748429e+09            8.724197                0.0                0.0
# 1.748429e+09            8.684862                0.0                0.0
# 1.748429e+09            8.527670                0.0                0.0
# 1.748429e+09            8.527670                0.0                0.0
#
#               liquidity-ratio-5-levels  rate-inst-volatility-20-sample  \
# timestamp
# 1.748352e+09                 89.331045                             NaN
# 1.748352e+09                 80.703789                             NaN
# 1.748352e+09                 80.734106                             NaN
# 1.748352e+09                 80.873083                             NaN
# 1.748352e+09                 80.873083                             NaN
# ...                                ...                             ...
# 1.748429e+09                  4.154360                   -3.963087e-07
# 1.748429e+09                  4.154360                   -3.963087e-07
# 1.748429e+09                  4.154342                   -3.963087e-07
# 1.748429e+09                  4.154342                   -3.963087e-07
# 1.748429e+09                  4.154279                    0.000000e+00
#
#               rate-momentum-20-sample  rate-mid-price-trend-20-sample  \
# timestamp
# 1.748352e+09                      NaN                             NaN
# 1.748352e+09                      NaN                             NaN
# 1.748352e+09                      NaN                             NaN
# 1.748352e+09                      NaN                             NaN
# 1.748352e+09                      NaN                             NaN
# ...                               ...                             ...
# 1.748429e+09            -1.455192e-11                        95999.95
# 1.748429e+09            -1.455192e-11                        95999.95
# 1.748429e+09            -1.455192e-11                        95999.95
# 1.748429e+09            -1.455192e-11                        95999.95
# 1.748429e+09            -1.455192e-11                        95999.95
#
#               rate-bid-volume-level-1  rate-ask-volume-level-1  \
# timestamp
# 1.748352e+09                      NaN                      NaN
# 1.748352e+09                      NaN                      NaN
# 1.748352e+09                      NaN                      NaN
# 1.748352e+09                      NaN                      NaN
# 1.748352e+09                      NaN                      NaN
# ...                               ...                      ...
# 1.748429e+09                 5.489714                 0.206013
# 1.748429e+09                 5.474462                 0.205871
# 1.748429e+09                 5.459209                 0.205728
# 1.748429e+09                 5.443956                 0.205586
# 1.748429e+09                 5.428695                 0.205443
#
#               V-bid-5-levels  V-ask-5-levels  inst-return  \
# timestamp
# 1.748352e+09        9.848354        0.110246          NaN
# 1.748352e+09        8.897237        0.110246          0.0
# 1.748352e+09        8.900579        0.110246          0.0
# 1.748352e+09        8.915901        0.110246          0.0
# 1.748352e+09        8.915901        0.110246          0.0
# ...                      ...             ...          ...
# 1.748429e+09       10.571378        2.544647          0.0
# 1.748429e+09       10.571378        2.544647          0.0
# 1.748429e+09       10.571378        2.544658          0.0
# 1.748429e+09       10.571378        2.544658          0.0
# 1.748429e+09       10.571218        2.544658          0.0
#
#               return-all-signed-for-5-ms  return-all-signed-for-10-ms  \
# timestamp
# 1.748352e+09                           0                            0
# 1.748352e+09                           0                            0
# 1.748352e+09                           0                            0
# 1.748352e+09                           0                            0
# 1.748352e+09                           0                            0
# ...                                  ...                          ...
# 1.748429e+09                          -1                           -1
# 1.748429e+09                          -1                           -1
# 1.748429e+09                          -1                           -1
# 1.748429e+09                          -1                           -1
# 1.748429e+09                          -1                           -1
#
#               return-all-signed-for-20-ms
# timestamp
# 1.748352e+09                            0
# 1.748352e+09                            0
# 1.748352e+09                            0
# 1.748352e+09                            0
# 1.748352e+09                            0
# ...                                   ...
# 1.748429e+09                           -1
# 1.748429e+09                           -1
# 1.748429e+09                           -1
# 1.748429e+09                           -1
# 1.748429e+09                           -1
#
# [1759607 rows x 18 columns]

# %%
df_eth
# Out:
#               bid-ask-imbalance-5-levels  spread  slope-bid-5-levels  \
# timestamp
# 1.748352e+09                    0.999078    0.01           -0.002545
# 1.748352e+09                    0.999078    0.01           -0.002545
# 1.748352e+09                    0.998962    0.01           -0.002866
# 1.748352e+09                    0.998704    0.01           -0.004111
# 1.748352e+09                    0.998926    0.01           -0.008078
# ...                                  ...     ...                 ...
# 1.748429e+09                   -0.353768    0.01           -0.005256
# 1.748429e+09                   -0.456580    0.01           -0.006772
# 1.748429e+09                   -0.591244    0.01           -0.009768
# 1.748429e+09                   -0.591262    0.01           -0.009536
# 1.748429e+09                   -0.353124    0.01           -0.004942
#
#               slope-ask-5-levels  vwap-bid-5-levels  vwap-ask-5-levels  \
# timestamp
# 1.748352e+09           11.613394                0.0                0.0
# 1.748352e+09           11.613394                0.0                0.0
# 1.748352e+09           11.613394                0.0                0.0
# 1.748352e+09           11.613394                0.0                0.0
# 1.748352e+09           11.613394                0.0                0.0
# ...                          ...                ...                ...
# 1.748429e+09            0.000777                0.0                0.0
# 1.748429e+09            0.000777                0.0                0.0
# 1.748429e+09            0.000777                0.0                0.0
# 1.748429e+09            0.000777                0.0                0.0
# 1.748429e+09            0.000777                0.0                0.0
#
#               liquidity-ratio-5-levels  rate-inst-volatility-20-sample  \
# timestamp
# 1.748352e+09               2169.263124                             NaN
# 1.748352e+09               2169.263124                             NaN
# 1.748352e+09               1926.505122                             NaN
# 1.748352e+09               1541.708195                             NaN
# 1.748352e+09               1861.984154                             NaN
# ...                                ...                             ...
# 1.748429e+09                  0.477357                             0.0
# 1.748429e+09                  0.373079                             0.0
# 1.748429e+09                  0.256878                             0.0
# 1.748429e+09                  0.256864                             0.0
# 1.748429e+09                  0.478061                             0.0
#
#               rate-momentum-20-sample  rate-mid-price-trend-20-sample  \
# timestamp
# 1.748352e+09                      NaN                             NaN
# 1.748352e+09                      NaN                             NaN
# 1.748352e+09                      NaN                             NaN
# 1.748352e+09                      NaN                             NaN
# 1.748352e+09                      NaN                             NaN
# ...                               ...                             ...
# 1.748429e+09                      0.0                        2328.675
# 1.748429e+09                      0.0                        2328.675
# 1.748429e+09                      0.0                        2328.675
# 1.748429e+09                      0.0                        2328.675
# 1.748429e+09                      0.0                        2328.675
#
#               rate-bid-volume-level-1  rate-ask-volume-level-1  \
# timestamp
# 1.748352e+09                      NaN                      NaN
# 1.748352e+09                      NaN                      NaN
# 1.748352e+09                      NaN                      NaN
# 1.748352e+09                      NaN                      NaN
# 1.748352e+09                      NaN                      NaN
# ...                               ...                      ...
# 1.748429e+09                 0.036235                53.060520
# 1.748429e+09                 0.036235                53.059859
# 1.748429e+09                 0.036235                53.059199
# 1.748429e+09                 0.036235                53.058539
# 1.748429e+09                 0.036235                53.057879
#
#               V-bid-5-levels  V-ask-5-levels  inst-return  \
# timestamp
# 1.748352e+09      113.941760        0.052526          NaN
# 1.748352e+09      113.941760        0.052526          0.0
# 1.748352e+09      101.190760        0.052526          0.0
# 1.748352e+09       80.979086        0.052526          0.0
# 1.748352e+09       97.801760        0.052526          0.0
# ...                      ...             ...          ...
# 1.748429e+09       79.904588      167.389407          0.0
# 1.748429e+09       62.449554      167.389407          0.0
# 1.748429e+09       42.998690      167.389407          0.0
# 1.748429e+09       42.996304      167.389407          0.0
# 1.748429e+09       80.022412      167.389407          0.0
#
#               return-all-signed-for-5-ms  return-all-signed-for-10-ms  \
# timestamp
# 1.748352e+09                           0                            0
# 1.748352e+09                           0                            0
# 1.748352e+09                           0                            0
# 1.748352e+09                           0                            0
# 1.748352e+09                           0                            0
# ...                                  ...                          ...
# 1.748429e+09                          -1                           -1
# 1.748429e+09                          -1                           -1
# 1.748429e+09                          -1                           -1
# 1.748429e+09                          -1                           -1
# 1.748429e+09                          -1                           -1
#
#               return-all-signed-for-20-ms
# timestamp
# 1.748352e+09                            0
# 1.748352e+09                            0
# 1.748352e+09                            0
# 1.748352e+09                            0
# 1.748352e+09                            0
# ...                                   ...
# 1.748429e+09                           -1
# 1.748429e+09                           -1
# 1.748429e+09                           -1
# 1.748429e+09                           -1
# 1.748429e+09                           -1
#
# [3033155 rows x 18 columns]

# %%
import numpy as np

target = df_eth["return-all-signed-for-5-ms"]

#pre_features = df_xbt[["return-all-signed-for-20-ms", "return-all-signed-for-10-ms", "return-all-signed-for-5-ms", "bid-ask-imbalance-5-levels", "spread"]]
pre_features = df_xbt[["bid-ask-imbalance-5-levels", "spread", "inst-return", "V-bid-5-levels", "V-ask-5-levels", "slope-bid-5-levels", "slope-ask-5-levels"]]

target_timestamp = target.index.values
feature_timestamp = pre_features.index.values
filtered_indicies = np.searchsorted(feature_timestamp, target_timestamp, side="left")

filtered_indicies = filtered_indicies[filtered_indicies < len(pre_features)]
pre_features_filtered = pre_features.iloc[filtered_indicies]

pre_features_filtered
# Out:
#               bid-ask-imbalance-5-levels  spread  inst-return  V-bid-5-levels  \
# timestamp
# 1.748352e+09                    0.977859     0.1          NaN        9.848354
# 1.748352e+09                    0.975572     0.1          0.0        8.915901
# 1.748352e+09                    0.975572     0.1          0.0        8.915901
# 1.748352e+09                    0.975572     0.1          0.0        8.915901
# 1.748352e+09                    0.975572     0.1          0.0        8.915901
# ...                                  ...     ...          ...             ...
# 1.748429e+09                    0.611973     0.1          0.0       10.571218
# 1.748429e+09                    0.611973     0.1          0.0       10.571218
# 1.748429e+09                    0.611973     0.1          0.0       10.571218
# 1.748429e+09                    0.611973     0.1          0.0       10.571218
# 1.748429e+09                    0.611973     0.1          0.0       10.571218
#
#               V-ask-5-levels  slope-bid-5-levels  slope-ask-5-levels
# timestamp
# 1.748352e+09        0.110246           -1.218478          365.547502
# 1.748352e+09        0.110246           -1.334694          365.547502
# 1.748352e+09        0.110246           -1.334694          365.547502
# 1.748352e+09        0.110246           -1.334694          365.547502
# 1.748352e+09        0.110246           -1.334694          365.547502
# ...                      ...                 ...                 ...
# 1.748429e+09        2.544658           -0.170274            8.527670
# 1.748429e+09        2.544658           -0.170274            8.527670
# 1.748429e+09        2.544658           -0.170274            8.527670
# 1.748429e+09        2.544658           -0.170274            8.527670
# 1.748429e+09        2.544658           -0.170274            8.527670
#
# [3033155 rows x 7 columns]

# %%
# Reset index of pre_features_filtered to match target's index
pre_features_aligned = pre_features_filtered.reset_index(drop=True)
pre_features_aligned.index = target.index

# Concatenate pre_features_aligned and target
combined_data = pd.concat([pre_features_aligned, target], axis=1)
combined_data.dropna(inplace=True)
combined_data
# Out:
#               bid-ask-imbalance-5-levels  spread  inst-return  V-bid-5-levels  \
# timestamp
# 1.748352e+09                    0.975572     0.1          0.0        8.915901
# 1.748352e+09                    0.975572     0.1          0.0        8.915901
# 1.748352e+09                    0.975572     0.1          0.0        8.915901
# 1.748352e+09                    0.975572     0.1          0.0        8.915901
# 1.748352e+09                    0.975572     0.1          0.0        8.915901
# ...                                  ...     ...          ...             ...
# 1.748429e+09                    0.611973     0.1          0.0       10.571218
# 1.748429e+09                    0.611973     0.1          0.0       10.571218
# 1.748429e+09                    0.611973     0.1          0.0       10.571218
# 1.748429e+09                    0.611973     0.1          0.0       10.571218
# 1.748429e+09                    0.611973     0.1          0.0       10.571218
#
#               V-ask-5-levels  slope-bid-5-levels  slope-ask-5-levels  \
# timestamp
# 1.748352e+09        0.110246           -1.334694          365.547502
# 1.748352e+09        0.110246           -1.334694          365.547502
# 1.748352e+09        0.110246           -1.334694          365.547502
# 1.748352e+09        0.110246           -1.334694          365.547502
# 1.748352e+09        0.110246           -1.334694          365.547502
# ...                      ...                 ...                 ...
# 1.748429e+09        2.544658           -0.170274            8.527670
# 1.748429e+09        2.544658           -0.170274            8.527670
# 1.748429e+09        2.544658           -0.170274            8.527670
# 1.748429e+09        2.544658           -0.170274            8.527670
# 1.748429e+09        2.544658           -0.170274            8.527670
#
#               return-all-signed-for-5-ms
# timestamp
# 1.748352e+09                           0
# 1.748352e+09                           0
# 1.748352e+09                           0
# 1.748352e+09                           0
# 1.748352e+09                           0
# ...                                  ...
# 1.748429e+09                          -1
# 1.748429e+09                          -1
# 1.748429e+09                          -1
# 1.748429e+09                          -1
# 1.748429e+09                          -1
#
# [3027555 rows x 8 columns]

# %%
target = combined_data["return-all-signed-for-5-ms"]
data = combined_data.drop(columns=["return-all-signed-for-5-ms"])
# Filter out rows where target equals 1
mask = target != 1
target = target[mask]
data = data[mask]

print(f"Data shape after filtering out class 1: {data.shape}")
print(f"Target shape after filtering out class 1: {target.shape}")
print("Remaining class distribution:")
print(target.value_counts().sort_index())
print(target.value_counts(normalize=True).sort_index())
# Out:
# Data shape after filtering out class 1: (3027555, 7)
# Target shape after filtering out class 1: (3027555,)
# Remaining class distribution:
# return-all-signed-for-5-ms
# -1     386143
#  0    2641412
# Name: count, dtype: int64

# %%
# Evaluate the model
y_pred_rf = rf_model.predict(data)
accuracy_rf = accuracy_score(target, y_pred_rf)
print(f"\nSmall Random Forest Accuracy: {accuracy_rf:.4f}")
print("\nClassification Report:")
print(classification_report(target, y_pred_rf, labels=[-1, 0]))
print("\nConfusion Matrix:")
print(confusion_matrix(target, y_pred_rf, labels=[-1, 0]))
# Out:
# Small Random Forest Accuracy: 0.2577
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.13      0.87      0.23    386143
#            0       0.90      0.17      0.28   2641412
#
#     accuracy                           0.26   3027555
#    macro avg       0.51      0.52      0.26   3027555
# weighted avg       0.80      0.26      0.28   3027555
#
#
# Confusion Matrix:
# [[ 334540   51603]
#  [2195731  445681]]

# %%
from matplotlib import pyplot as plt

plt.plot(df_eth["inst-return"].iloc[30000:40000])
